# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Agricultural_Dataset.csv')

# %%
data.head()
# Out:
#       District  year  area  avg_rainfall  max_temperature  min_temperature  \
# 0        dhaka  2008   NaN          2385             34.2             12.5
# 1      gazipur  2008   NaN          2197             30.2             19.5
# 2    narsingdi  2008   NaN          2197             34.2             12.5
# 3  narayangonj  2008   NaN          2197             34.2             12.2
# 4      tangail  2008   NaN          1856             34.1             10.2
#
#     aus    aman    boro  wheat  ...  Noncalcareous Brown Floodplain Soil  \
# 0   804    9691  233939   1129  ...                                    0
# 1  4328   93956  208434    479  ...                                   13
# 2   484   93958  207669   2073  ...                                    0
# 3  1617   14485  129390   4585  ...                                    0
# 4   447  170918  672851  17477  ...                                  566
#
#    Shallow Red-Brown Terrace Soil  Deep Red-Brown Terrace Soil  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='avg_rainfall', y='wheat', data= data)
plt.title("Scatter plot of average rainfall vs wheat production")
plt.xlabel("Average rainfall")
plt.ylabel("Wheat production")
plt.grid(True)
plt.show()

# %%
#Crop prudction for potato
plt.figure(figsize=(10,5))
sns.scatterplot(x='avg_rainfall', y='potato', data= data)
plt.title("Scatter plot of average rainfall vs potato")
plt.xlabel("Average rainfall")
plt.ylabel("Wheat production")
plt.grid(True)
plt.show()

# %%
#data.info()
#data.describe()
data.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'area'}>,
#         <Axes: title={'center': 'avg_rainfall'}>,
#         <Axes: title={'center': 'max_temperature'}>,
#         <Axes: title={'center': 'min_temperature'}>,
#         <Axes: title={'center': 'aus'}>],
#        [<Axes: title={'center': 'aman'}>,
#         <Axes: title={'center': 'boro'}>,
#         <Axes: title={'center': 'wheat'}>,
#         <Axes: title={'center': 'potato'}>,
#         <Axes: title={'center': 'jute'}>,
#         <Axes: title={'center': 'humidity'}>],
#        [<Axes: title={'center': 'urea'}>,
#         <Axes: title={'center': 'tsp'}>, <Axes: title={'center': 'mp'}>,
#         <Axes: title={'center': 'DAP'}>,
#         <Axes: title={'center': 'inundationland_Highland'}>,
#         <Axes: title={'center': 'inundationland_mediumhighland'}>],
#        [<Axes: title={'center': 'inundationland_lowland'}>,
#         <Axes: title={'center': 'inundationland_mediumlowland'}>,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#box plot to check if there is outlier for average rainfall
sns.boxplot(x=data['wheat'], color='green')
plt.title('Box Plot')
plt.show()

# %%
import numpy as np
q1 = data['wheat'].quantile(0.25)
q3 = data['wheat'].quantile(0.75)

#iqr it finds out the inter quartile range
iqr = q3 - q1
lower_bound = q1 -1.5*iqr
upper_bound = q3 + 1.5*iqr

#Define the lower and upper bound
Lower_bound = q1-1.5*iqr
Upper_bound = q3+1.5*iqr

#Cap the outliers
data['wheat_capped'] = np.where(data['wheat'] > upper_bound, upper_bound, np.where(data['wheat'] < lower_bound, lower_bound, data['wheat']))

# %%
sns.boxplot(x=data['wheat_capped'], color='orange')
# Out:
# <Axes: xlabel='wheat_capped'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Scatter plot to visualize the relationship
data1 = data[['avg_rainfall','humidity','wheat_capped']]

# sns.pairplot(data1)
# plt.show()

#Correlation matrix
Correlation_matrix = data1.corr()
sns.heatmap(Correlation_matrix, annot = True)
plt.show()

# %%
#Crop production for Jute and Potatoe

# plt.figure(figsize=(10,5))
# sns.scatterplot(x='avg_rainfall', y='jute', data= data)
# plt.title("Scatter plot of average rainfall vs Jute")
# plt.xlabel("Average rainfall")
# plt.ylabel("Jute production")
# plt.grid(True)
# plt.show()

# %%
#Humidity affecting Crop prudction for potato and humidity

# plt.figure(figsize=(10,5))
# sns.scatterplot(x='humidity', y='potato', data= data)
# plt.title("Scatter plot of humidity vs potato")
# plt.xlabel("Average humidity")
# plt.ylabel("Wheat production")
# plt.grid(True)
# plt.show()

# %%
#Humidity affecting Crop prudction for wheat

# plt.figure(figsize=(10,5))
# sns.scatterplot(x='humidity', y='wheat', data= data)
# plt.title("Scatter plot of humidity vs potato")
# plt.xlabel("Average humidity")
# plt.ylabel("Wheat production")
# plt.grid(True)
# plt.show()

# %%
#Humidity affecting crop production for Jute
#Humidity affecting Crop prudction for wheat

# plt.figure(figsize=(10,5))
# sns.scatterplot(x='humidity', y='jute', data= data)
# plt.title("Scatter plot of humidity vs jute")
# plt.xlabel("Average humidity")
# plt.ylabel("Wheat production")
# plt.grid(True)
# plt.show()

# %%
# import os
# from pathlib import Path

# IMAGES_PATH = Path("C:\\Users\\USER\\Desktop\\CSE445\\Images")

# # Ensure that the directory exists, create it if it doesn't
# os.makedirs(IMAGES_PATH, exist_ok=True)

# def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
#   #Construct the full path for file

#     path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
#     if tight_layout:
#        plt.tight_layout()
#        plt.savefig(path, format=fig_extension, dpi=resolution)

# #save the figure

# %%
#Preprocessing the datavalues
data.info()
print(data.isnull().sum())

# %%
#checking for outliers
plt.figure(figsize=(20,5))
sns.boxplot(data=data['jute'])
plt.show()

# Box Plot
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y=data['jute'])
plt.title('Box Plot')

# %%
# from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Assuming X_train and X_test are your feature matrices
# Initialize the scalers
# scaler_standard = StandardScaler()
# scaler_minmax = MinMaxScaler()

# # Fit and transform the training data
# X_train_standardized = scaler_standard.fit_transform(X_train)
# X_train_normalized = scaler_minmax.fit_transform(X_train)

# # Transform the testing data using the same scaler
# X_test_standardized = scaler_standard.transform(X_test)
# X_test_normalized = scaler_minmax.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bbdb5fbbd563> in <cell line: 5>()
#       3 # Assuming X_train and X_test are your feature matrices
#       4 # Initialize the scalers
# ----> 5 scaler_standard = StandardScaler()
#       6 scaler_minmax = MinMaxScaler()
#       7
#
# NameError: name 'StandardScaler' is not defined

# %%
data['wheat'].hist(bins=30)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of avg_rainfall')
plt.show()

# Perform Shapiro-Wilk test
stat, p = shapiro(data['avg_rainfall'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')

# %%
len(test_set)

# %%
#Columns to normalize dataset values
# Select columns to normalize
from sklearn.preprocessing import MinMaxScaler
columns_to_normalize = ['avg_rainfall','humidity','wheat']

scaler = MinMaxScaler()

train_set[columns_to_normalize] = scaler.fit_transform(train_set[columns_to_normalize])
test_set[columns_to_normalize] = scaler.transform(test_set[columns_to_normalize])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b37bdd53f4fc> in <cell line: 8>()
#       6 scaler = MinMaxScaler()
#       7
# ----> 8 train_set[columns_to_normalize] = scaler.fit_transform(train_set[columns_to_normalize])
#       9 test_set[columns_to_normalize] = scaler.transform(test_set[columns_to_normalize])
#
# NameError: name 'train_set' is not defined

# %%
train_set.head()
test_set.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-80e478a7adc7> in <cell line: 1>()
# ----> 1 train_set.head()
#       2 test_set.head()
#
# NameError: name 'train_set' is not defined

# %%
from sklearn.model_selection import train_test_split
from scipy.stats import shapiro

X = data[['avg_rainfall','humidity']]
y = data['wheat_capped']

train_set, test_set = train_test_split(data, test_size =0.2 , random_state=42)

X_train = train_set[['avg_rainfall','humidity']]  #feature column
Y_train = train_set[['wheat_capped']] #Target column

X_test = train_set[['avg_rainfall','humidity']]  #feature column
Y_test = train_set[['wheat_capped']] #Target column

# %%
# Y_pred = model.predict(X_test)

# %%
#Training done using random forest regressor model

# from sklearn.ensemble import RandomForestRegressor
# model = RandomForestRegressor()
# model.fit(X_train, Y_train)

# Y_pred = model.predict(X_test)
# # Y_pred = model.predict(X_test)
# Out:
# <ipython-input-24-97b7782442bf>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, Y_train)

# %%
#Initialize the Linear Regression training model

# model = LinearRegression()
# model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#  from sklearn.svm import SVR

# #Initialize and train the model
#  model = RandomForestRegressor(n_estimators=100, random_state=42)
#  model.fit(X_train, Y_train)
# Out:
# <ipython-input-55-608e54828200>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, Y_train)
# RandomForestRegressor(random_state=42)

# %%
# from sklearn.ensemble import GradientBoostingRegressor

# #Train a graident booster regression model
# model = GradientBoostingRegressor(n_estimators =100 , random_state=42)
# model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor(random_state=42)

# %%
#Xtreme gradient boosting
# from xgboost import XGBRegressor
# model = XGBRegressor(n_estimators=100, random_state=42)
# model.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
#KNN Regressor
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(5)
model.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor()

# %%
#scattering the linear regression plot
Y_pred = model.predict(X_test)

# %%
#Scatter plot
#plt.scatter()
plt.scatter(Y_test, Y_pred, color='blue', alpha = 0.5)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'k--', lw=2)  # Add diagonal line
plt.xlabel("Actual Wheat Production")
plt.ylabel("Predicted Wheat Production")
plt.title("Actual vs Predicted Wheat Production")
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted Wheat Production')

# %%
#Determine MSE score and r^2 score
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(mse)
print(r2)
# Out:
# 10847247.809508929
# 0.2680011072595928

# %%
 #Visualize the results
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.scatter(X_test, Y_test, color='blue')
plt.scatter(X_test, Y_pred, color = 'red')
plt.xlabel('Average rainfall')
plt.ylabel('Wheat Production')
plt.title('Average Rainfall vs Wheat production using Random Forest Regressor')
plt.show()
